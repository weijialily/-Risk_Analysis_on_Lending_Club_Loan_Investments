# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import json
import requests

# %% [markdown]
# ## 1. Current data from Lending Club

# %% [markdown]
# Fetch current listed loan through API.

# %%
api_key = open('../input/api_key.txt', 'r').read()

headers = {'Authorization': api_key}
url = 'https://api.lendingclub.com/api/investor/v1/loans/listing'

r = requests.get(url, headers=headers)
type(r.json())
# Out:
# dict

# %%
# Show the contents of the downloaded JSON file. Current Loan information is saved under 'loan' tag.
r.json()
# Out:
# {'asOfDate': '2018-02-22T10:50:20.167-08:00',
#  'loans': [{'accNowDelinq': 0,
#    'accOpenPast24Mths': 0,
#    'acceptD': '2018-02-08T12:41:11.000-08:00',
#    'addrState': 'NY',
#    'addrZip': '105xx',
#    'allUtil': 19.1,
#    'annualInc': 15000.0,
#    'annualIncJoint': 58615.0,
#    'applicationType': 'JOINT',
#    'avgCurBal': 3321,
#    'bcOpenToBuy': None,
#    'bcUtil': None,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-08T12:36:32.000-08:00',
#    'delinq2Yrs': 2,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 23.52,
#    'dtiJoint': 10.52,
#    'earliestCrLine': '2007-02-07T16:00:00.000-08:00',
#    'empLength': 60,
#    'empTitle': 'Manager',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 15.42,
#    'ficoRangeHigh': 664,
#    'ficoRangeLow': 660,
#    'fundedAmount': 125.0,
#    'grade': 'E',
#    'homeOwnership': 'RENT',
#    'housingPayment': 400.0,
#    'iLUtil': 19.1,
#    'id': 128019062,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 173.33,
#    'intRate': 23.88,
#    'investorCount': None,
#    'isIncV': 'SOURCE_VERIFIED',
#    'isIncVJoint': 'SOURCE_VERIFIED',
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 4425.0,
#    'maxBalBc': 0.0,
#    'memberId': 140867885,
#    'moSinOldIlAcct': 126,
#    'moSinOldRevTlOp': 132,
#    'moSinRcntRevTlOp': 53,
#    'moSinRcntTl': 53,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': 5,
#    'mthsSinceLastMajorDerog': 5,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 62,
#    'mthsSinceRecentBc': None,
#    'mthsSinceRecentBcDlq': 17,
#    'mthsSinceRecentInq': None,
#    'mthsSinceRecentRevolDelinq': 5,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 0,
#    'numActvRevTl': 0,
#    'numBcSats': 0,
#    'numBcTl': 4,
#    'numIlTl': 3,
#    'numOpRevTl': 0,
#    'numRevAccts': 8,
#    'numRevTlBalGt0': 0,
#    'numSats': 1,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 1,
#    'numTlOpPast12m': 0,
#    'openAcc': 1,
#    'openAcc6m': 0,
#    'openActIl': 1,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'pctTlNvrDlq': 72,
#    'percentBcGt75': None,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'moving',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:59:22.000-08:00',
#    'revolBal': 0.0,
#    'revolBalJoint': 13,
#    'revolUtil': None,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 0,
#    'secAppEarliestCrLine': '2008-09-29T17:00:00.000-07:00',
#    'secAppFicoRangeHigh': 549,
#    'secAppFicoRangeLow': 545,
#    'secAppInqLast6Mths': 1,
#    'secAppMortAcc': 0,
#    'secAppMthsSinceLastMajorDerog': 1,
#    'secAppNumRevAccts': 0,
#    'secAppOpenAcc': 5,
#    'secAppOpenActIl': 5,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.48,
#    'subGrade': 'E2',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 350,
#    'totCurBal': 3321,
#    'totHiCredLim': 17428,
#    'totalAcc': 11,
#    'totalBalExMort': 3321,
#    'totalBalIl': 3321.0,
#    'totalBcLimit': 0,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 17428,
#    'totalRevHiLim': 0},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'acceptD': '2018-02-16T10:34:20.000-08:00',
#    'addrState': 'KY',
#    'addrZip': '402xx',
#    'allUtil': 71.8,
#    'annualInc': 39492.0,
#    'annualIncJoint': 68568.0,
#    'applicationType': 'JOINT',
#    'avgCurBal': 24445,
#    'bcOpenToBuy': 4565,
#    'bcUtil': 32.9,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-16T10:25:22.000-08:00',
#    'delinq2Yrs': 1,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 27.68,
#    'dtiJoint': 19.88,
#    'earliestCrLine': '1992-11-15T16:00:00.000-08:00',
#    'empLength': 36,
#    'empTitle': 'Enumerator',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 7.0,
#    'ficoRangeHigh': 684,
#    'ficoRangeLow': 680,
#    'fundedAmount': 2950.0,
#    'grade': 'C',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 946.0,
#    'iLUtil': 84.6,
#    'id': 128912835,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 5,
#    'inqLast6Mths': 0,
#    'installment': 277.52,
#    'intRate': 15.05,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': 'NOT_VERIFIED',
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 8000.0,
#    'maxBalBc': 1684.0,
#    'memberId': 141724515,
#    'moSinOldIlAcct': 166,
#    'moSinOldRevTlOp': 303,
#    'moSinRcntRevTlOp': 9,
#    'moSinRcntTl': 9,
#    'mortAcc': 2,
#    'mtgPayment': 946.24,
#    'mthsSinceLastDelinq': 14,
#    'mthsSinceLastMajorDerog': 28,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 60,
#    'mthsSinceRecentBc': 9,
#    'mthsSinceRecentBcDlq': 14,
#    'mthsSinceRecentInq': 2,
#    'mthsSinceRecentRevolDelinq': 14,
#    'numAcctsEver120Ppd': 2,
#    'numActvBcTl': 3,
#    'numActvRevTl': 4,
#    'numBcSats': 4,
#    'numBcTl': 13,
#    'numIlTl': 7,
#    'numOpRevTl': 5,
#    'numRevAccts': 21,
#    'numRevTlBalGt0': 4,
#    'numSats': 7,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 2,
#    'openAcc': 7,
#    'openAcc6m': 0,
#    'openActIl': 1,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 2,
#    'openRv24m': 2,
#    'pctTlNvrDlq': 63,
#    'percentBcGt75': 25.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:03:41.000-08:00',
#    'revolBal': 2572.0,
#    'revolBalJoint': 10490,
#    'revolUtil': 32.1,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 0,
#    'secAppEarliestCrLine': '1996-08-15T17:00:00.000-07:00',
#    'secAppFicoRangeHigh': 644,
#    'secAppFicoRangeLow': 640,
#    'secAppInqLast6Mths': 0,
#    'secAppMortAcc': 2,
#    'secAppMthsSinceLastMajorDerog': 28,
#    'secAppNumRevAccts': 11,
#    'secAppOpenAcc': 4,
#    'secAppOpenActIl': 1,
#    'secAppRevolUtil': 48.8,
#    'serviceFeeRate': 1.07,
#    'subGrade': 'C4',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 171115,
#    'totHiCredLim': 184164,
#    'totalAcc': 30,
#    'totalBalExMort': 23681,
#    'totalBalIl': 21109.0,
#    'totalBcLimit': 6800,
#    'totalCuTl': 6,
#    'totalIlHighCreditLimit': 24964,
#    'totalRevHiLim': 8000},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'acceptD': '2018-02-18T09:28:58.000-08:00',
#    'addrState': 'MI',
#    'addrZip': '484xx',
#    'allUtil': 102.0,
#    'annualInc': 14996.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 1307,
#    'bcOpenToBuy': 1283,
#    'bcUtil': 102.0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-18T09:27:42.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 10.41,
#    'dtiJoint': None,
#    'earliestCrLine': '1979-04-17T16:00:00.000-08:00',
#    'empLength': None,
#    'empTitle': None,
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 15.42,
#    'ficoRangeHigh': 674,
#    'ficoRangeLow': 670,
#    'fundedAmount': 275.0,
#    'grade': 'E',
#    'homeOwnership': 'RENT',
#    'housingPayment': 500.0,
#    'iLUtil': 0.0,
#    'id': 129019538,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 1,
#    'inqLast6Mths': 2,
#    'installment': 117.06,
#    'intRate': 24.85,
#    'investorCount': None,
#    'isIncV': 'VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 2950.0,
#    'maxBalBc': 1473.0,
#    'memberId': 141902508,
#    'moSinOldIlAcct': 466,
#    'moSinOldRevTlOp': 26,
#    'moSinRcntRevTlOp': 15,
#    'moSinRcntTl': 15,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 466,
#    'mthsSinceRecentBc': 15,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 5,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 3,
#    'numActvRevTl': 3,
#    'numBcSats': 3,
#    'numBcTl': 3,
#    'numIlTl': 1,
#    'numOpRevTl': 3,
#    'numRevAccts': 3,
#    'numRevTlBalGt0': 3,
#    'numSats': 3,
#    'numTl120dpd2m': None,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 3,
#    'openAcc6m': 0,
#    'openActIl': 0,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 0,
#    'openRv24m': 2,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 100.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:31:24.000-08:00',
#    'revolBal': 3923.0,
#    'revolBalJoint': None,
#    'revolUtil': 102.0,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.48,
#    'subGrade': 'E3',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 3923,
#    'totHiCredLim': 3850,
#    'totalAcc': 4,
#    'totalBalExMort': 3923,
#    'totalBalIl': 0.0,
#    'totalBcLimit': 3850,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 0,
#    'totalRevHiLim': 3850},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 9,
#    'acceptD': '2018-02-16T08:52:38.000-08:00',
#    'addrState': 'AR',
#    'addrZip': '716xx',
#    'allUtil': 55.0,
#    'annualInc': 50000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 3665,
#    'bcOpenToBuy': 620,
#    'bcUtil': 63.0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-14T15:37:04.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 32.09,
#    'dtiJoint': None,
#    'earliestCrLine': '2014-03-13T17:00:00.000-07:00',
#    'empLength': 120,
#    'empTitle': 'Master electrician',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 15.42,
#    'ficoRangeHigh': 664,
#    'ficoRangeLow': 660,
#    'fundedAmount': 175.0,
#    'grade': 'E',
#    'homeOwnership': 'RENT',
#    'housingPayment': 300.0,
#    'iLUtil': 68.0,
#    'id': 128787351,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 3,
#    'inqLast6Mths': 1,
#    'installment': 160.6,
#    'intRate': 23.88,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 4100.0,
#    'maxBalBc': 920.0,
#    'memberId': 141387448,
#    'moSinOldIlAcct': 47,
#    'moSinOldRevTlOp': 22,
#    'moSinRcntRevTlOp': 1,
#    'moSinRcntTl': 1,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': 41,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 15,
#    'mthsSinceRecentBc': 3,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 1,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 5,
#    'numActvRevTl': 8,
#    'numBcSats': 5,
#    'numBcTl': 5,
#    'numIlTl': 2,
#    'numOpRevTl': 8,
#    'numRevAccts': 8,
#    'numRevTlBalGt0': 7,
#    'numSats': 10,
#    'numTl120dpd2m': None,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 6,
#    'openAcc': 10,
#    'openAcc6m': 3,
#    'openActIl': 2,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 6,
#    'openRv24m': 8,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 60.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'small_business',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:21:07.000-08:00',
#    'revolBal': 4117.0,
#    'revolBalJoint': None,
#    'revolUtil': 55.0,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.48,
#    'subGrade': 'E2',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 133,
#    'totCurBal': 36653,
#    'totHiCredLim': 55173,
#    'totalAcc': 10,
#    'totalBalExMort': 36653,
#    'totalBalIl': 32536.0,
#    'totalBcLimit': 3100,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 47673,
#    'totalRevHiLim': 7500},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'acceptD': '2018-02-22T07:57:45.000-08:00',
#    'addrState': 'MD',
#    'addrZip': '212xx',
#    'allUtil': 39.7,
#    'annualInc': 57106.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 5260,
#    'bcOpenToBuy': 13095,
#    'bcUtil': 46.6,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-22T07:54:21.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 20.39,
#    'dtiJoint': None,
#    'earliestCrLine': '2004-08-21T17:00:00.000-07:00',
#    'empLength': 96,
#    'empTitle': 'Program Assistant',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 1.86,
#    'ficoRangeHigh': 789,
#    'ficoRangeLow': 785,
#    'fundedAmount': 1850.0,
#    'grade': 'A',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 683.0,
#    'iLUtil': 53.4,
#    'id': 129173352,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 186.2,
#    'intRate': 7.34,
#    'investorCount': None,
#    'isIncV': 'SOURCE_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 6000.0,
#    'maxBalBc': 9339.0,
#    'memberId': 142258660,
#    'moSinOldIlAcct': 137,
#    'moSinOldRevTlOp': 162,
#    'moSinRcntRevTlOp': 28,
#    'moSinRcntTl': 22,
#    'mortAcc': 3,
#    'mtgPayment': 207.96,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 22,
#    'mthsSinceRecentBc': 28,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 14,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 2,
#    'numActvRevTl': 3,
#    'numBcSats': 3,
#    'numBcTl': 5,
#    'numIlTl': 10,
#    'numOpRevTl': 7,
#    'numRevAccts': 12,
#    'numRevTlBalGt0': 3,
#    'numSats': 11,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 11,
#    'openAcc6m': 0,
#    'openActIl': 2,
#    'openIl12m': 0,
#    'openIl24m': 2,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 33.3,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'credit_card',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:01:43.000-08:00',
#    'revolBal': 11470.0,
#    'revolBalJoint': None,
#    'revolUtil': 27.9,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.83,
#    'subGrade': 'A4',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 52598,
#    'totHiCredLim': 105565,
#    'totalAcc': 25,
#    'totalBalExMort': 30258,
#    'totalBalIl': 18788.0,
#    'totalBcLimit': 24500,
#    'totalCuTl': 4,
#    'totalIlHighCreditLimit': 35165,
#    'totalRevHiLim': 41100},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 7,
#    'acceptD': '2018-02-21T10:22:45.000-08:00',
#    'addrState': 'CA',
#    'addrZip': '952xx',
#    'allUtil': 80.8,
#    'annualInc': 98000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 5855,
#    'bcOpenToBuy': 12126,
#    'bcUtil': 77.5,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-17T16:12:01.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'dti': 29.49,
#    'dtiJoint': None,
#    'earliestCrLine': '2007-12-17T16:00:00.000-08:00',
#    'empLength': 0,
#    'empTitle': 'Coordinator IV',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 15.42,
#    'ficoRangeHigh': 684,
#    'ficoRangeLow': 680,
#    'fundedAmount': 19100.0,
#    'grade': 'E',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 1132.0,
#    'iLUtil': 85.0,
#    'id': 129016296,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 2,
#    'inqLast6Mths': 1,
#    'installment': 992.02,
#    'intRate': 24.85,
#    'investorCount': None,
#    'isIncV': 'VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 25000.0,
#    'maxBalBc': 17339.0,
#    'memberId': 141879118,
#    'moSinOldIlAcct': 72,
#    'moSinOldRevTlOp': 122,
#    'moSinRcntRevTlOp': 2,
#    'moSinRcntTl': 2,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 7,
#    'mthsSinceRecentBc': 2,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 2,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 8,
#    'numActvRevTl': 10,
#    'numBcSats': 8,
#    'numBcTl': 10,
#    'numIlTl': 15,
#    'numOpRevTl': 12,
#    'numRevAccts': 14,
#    'numRevTlBalGt0': 10,
#    'numSats': 26,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 4,
#    'openAcc': 26,
#    'openAcc6m': 2,
#    'openActIl': 14,
#    'openIl12m': 1,
#    'openIl24m': 4,
#    'openRv12m': 3,
#    'openRv24m': 3,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 37.5,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T07:44:17.000-08:00',
#    'revolBal': 44312.0,
#    'revolBalJoint': None,
#    'revolUtil': 73.5,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.48,
#    'subGrade': 'E3',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 152220,
#    'totHiCredLim': 204637,
#    'totalAcc': 29,
#    'totalBalExMort': 152220,
#    'totalBalIl': 107908.0,
#    'totalBcLimit': 53800,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 144337,
#    'totalRevHiLim': 60300},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'acceptD': '2018-02-20T22:53:51.000-08:00',
#    'addrState': 'CA',
#    'addrZip': '902xx',
#    'allUtil': 44.9,
#    'annualInc': 55000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 2649,
#    'bcOpenToBuy': 1725,
#    'bcUtil': 84.9,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-20T22:46:46.000-08:00',
#    'delinq2Yrs': 3,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'dti': 28.89,
#    'dtiJoint': None,
#    'earliestCrLine': '2005-06-20T17:00:00.000-07:00',
#    'empLength': 84,
#    'empTitle': 'Executive Administrative Assistant ',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 14.72,
#    'ficoRangeHigh': 699,
#    'ficoRangeLow': 695,
#    'fundedAmount': 3925.0,
#    'grade': 'E',
#    'homeOwnership': 'RENT',
#    'housingPayment': 0.0,
#    'iLUtil': 48.9,
#    'id': 129111700,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 386.58,
#    'intRate': 22.9,
#    'investorCount': None,
#    'isIncV': 'SOURCE_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 10000.0,
#    'maxBalBc': 7865.0,
#    'memberId': 142056381,
#    'moSinOldIlAcct': 103,
#    'moSinOldRevTlOp': 152,
#    'moSinRcntRevTlOp': 19,
#    'moSinRcntTl': 19,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': 11,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 24,
#    'mthsSinceRecentBc': 19,
#    'mthsSinceRecentBcDlq': 11,
#    'mthsSinceRecentInq': 19,
#    'mthsSinceRecentRevolDelinq': 11,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 2,
#    'numActvRevTl': 3,
#    'numBcSats': 2,
#    'numBcTl': 7,
#    'numIlTl': 6,
#    'numOpRevTl': 10,
#    'numRevAccts': 19,
#    'numRevTlBalGt0': 3,
#    'numSats': 12,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 12,
#    'openAcc6m': 0,
#    'openActIl': 2,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 0,
#    'openRv24m': 1,
#    'pctTlNvrDlq': 88,
#    'percentBcGt75': 50.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:48:51.000-08:00',
#    'revolBal': 10313.0,
#    'revolBalJoint': None,
#    'revolUtil': 38.3,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.58,
#    'subGrade': 'E1',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 31789,
#    'totHiCredLim': 70849,
#    'totalAcc': 25,
#    'totalBalExMort': 31789,
#    'totalBalIl': 21476.0,
#    'totalBcLimit': 11400,
#    'totalCuTl': 1,
#    'totalIlHighCreditLimit': 43949,
#    'totalRevHiLim': 26900},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 1,
#    'acceptD': '2018-02-21T10:42:10.000-08:00',
#    'addrState': 'WA',
#    'addrZip': '980xx',
#    'allUtil': 84.4,
#    'annualInc': 230000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 2311,
#    'bcOpenToBuy': 2604,
#    'bcUtil': 84.1,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-21T10:35:57.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 3.99,
#    'dtiJoint': None,
#    'earliestCrLine': '1999-10-20T17:00:00.000-07:00',
#    'empLength': 108,
#    'empTitle': 'Property Manager ',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 6.8,
#    'ficoRangeHigh': 664,
#    'ficoRangeLow': 660,
#    'fundedAmount': 18050.0,
#    'grade': 'C',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 2802.0,
#    'iLUtil': None,
#    'id': 129126514,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 2,
#    'inqLast12m': 3,
#    'inqLast6Mths': 0,
#    'installment': 837.67,
#    'intRate': 12.61,
#    'investorCount': None,
#    'isIncV': 'SOURCE_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 25000.0,
#    'maxBalBc': 7253.0,
#    'memberId': 142181450,
#    'moSinOldIlAcct': 131,
#    'moSinOldRevTlOp': 220,
#    'moSinRcntRevTlOp': 19,
#    'moSinRcntTl': 19,
#    'mortAcc': 4,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': 42,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 131,
#    'mthsSinceRecentBc': 27,
#    'mthsSinceRecentBcDlq': 47,
#    'mthsSinceRecentInq': 0,
#    'mthsSinceRecentRevolDelinq': 42,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 5,
#    'numActvRevTl': 10,
#    'numBcSats': 5,
#    'numBcTl': 7,
#    'numIlTl': 1,
#    'numOpRevTl': 10,
#    'numRevAccts': 12,
#    'numRevTlBalGt0': 10,
#    'numSats': 10,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 10,
#    'openAcc6m': 0,
#    'openActIl': 0,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 0,
#    'openRv24m': 1,
#    'pctTlNvrDlq': 88,
#    'percentBcGt75': 100.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:27:47.000-08:00',
#    'revolBal': 23112.0,
#    'revolBalJoint': None,
#    'revolUtil': 84.4,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.13,
#    'subGrade': 'C1',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 157,
#    'totCurBal': 23112,
#    'totHiCredLim': 27400,
#    'totalAcc': 17,
#    'totalBalExMort': 23112,
#    'totalBalIl': 0.0,
#    'totalBcLimit': 16400,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 0,
#    'totalRevHiLim': 27400},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 7,
#    'acceptD': '2018-02-21T10:47:29.000-08:00',
#    'addrState': 'DC',
#    'addrZip': '200xx',
#    'allUtil': 60.3,
#    'annualInc': 124500.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 37161,
#    'bcOpenToBuy': 12350,
#    'bcUtil': 52.3,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-01-30T06:01:52.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'dti': 5.26,
#    'dtiJoint': None,
#    'earliestCrLine': '2007-02-27T16:00:00.000-08:00',
#    'empLength': 24,
#    'empTitle': 'Sr. Associate',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 14.72,
#    'ficoRangeHigh': 674,
#    'ficoRangeLow': 670,
#    'fundedAmount': 9050.0,
#    'grade': 'E',
#    'homeOwnership': 'RENT',
#    'housingPayment': 2600.0,
#    'iLUtil': 86.3,
#    'id': 127946290,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 3,
#    'inqLast12m': 16,
#    'inqLast6Mths': 2,
#    'installment': 626.64,
#    'intRate': 23.87,
#    'investorCount': None,
#    'isIncV': 'VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 16000.0,
#    'maxBalBc': 4495.0,
#    'memberId': 140098112,
#    'moSinOldIlAcct': 131,
#    'moSinOldRevTlOp': 128,
#    'moSinRcntRevTlOp': 7,
#    'moSinRcntTl': 7,
#    'mortAcc': 2,
#    'mtgPayment': 2981.78,
#    'mthsSinceLastDelinq': 38,
#    'mthsSinceLastMajorDerog': 75,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 7,
#    'mthsSinceRecentBc': 12,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 0,
#    'mthsSinceRecentRevolDelinq': 38,
#    'numAcctsEver120Ppd': 1,
#    'numActvBcTl': 8,
#    'numActvRevTl': 9,
#    'numBcSats': 9,
#    'numBcTl': 12,
#    'numIlTl': 7,
#    'numOpRevTl': 11,
#    'numRevAccts': 16,
#    'numRevTlBalGt0': 9,
#    'numSats': 13,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 5,
#    'openAcc': 13,
#    'openAcc6m': 0,
#    'openActIl': 1,
#    'openIl12m': 2,
#    'openIl24m': 2,
#    'openRv12m': 3,
#    'openRv24m': 5,
#    'pctTlNvrDlq': 91,
#    'percentBcGt75': 25.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'home_improvement',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:12:14.000-08:00',
#    'revolBal': 14285.0,
#    'revolBalJoint': None,
#    'revolUtil': 48.1,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.58,
#    'subGrade': 'E2',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 445927,
#    'totHiCredLim': 476137,
#    'totalAcc': 26,
#    'totalBalExMort': 26363,
#    'totalBalIl': 12078.0,
#    'totalBcLimit': 25900,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 14000,
#    'totalRevHiLim': 29700},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'acceptD': '2018-02-22T08:24:34.000-08:00',
#    'addrState': 'NJ',
#    'addrZip': '077xx',
#    'allUtil': 64.2,
#    'annualInc': 106000.0,
#    'annualIncJoint': 131000.0,
#    'applicationType': 'JOINT',
#    'avgCurBal': 59563,
#    'bcOpenToBuy': None,
#    'bcUtil': None,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-22T08:15:15.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 13.8,
#    'dtiJoint': 13.52,
#    'earliestCrLine': '1992-10-21T17:00:00.000-07:00',
#    'empLength': 48,
#    'empTitle': 'Customer Support Analyst',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 1.86,
#    'ficoRangeHigh': 704,
#    'ficoRangeLow': 700,
#    'fundedAmount': 775.0,
#    'grade': 'A',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 2318.0,
#    'iLUtil': 65.0,
#    'id': 129170948,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 2,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 304.54,
#    'intRate': 6.07,
#    'investorCount': None,
#    'isIncV': 'SOURCE_VERIFIED',
#    'isIncVJoint': 'NOT_VERIFIED',
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 10000.0,
#    'maxBalBc': 0.0,
#    'memberId': 142277116,
#    'moSinOldIlAcct': 187,
#    'moSinOldRevTlOp': 304,
#    'moSinRcntRevTlOp': 12,
#    'moSinRcntTl': 12,
#    'mortAcc': 2,
#    'mtgPayment': 2317.61,
#    'mthsSinceLastDelinq': 47,
#    'mthsSinceLastMajorDerog': 47,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 25,
#    'mthsSinceRecentBc': None,
#    'mthsSinceRecentBcDlq': 47,
#    'mthsSinceRecentInq': 18,
#    'mthsSinceRecentRevolDelinq': 47,
#    'numAcctsEver120Ppd': 4,
#    'numActvBcTl': 0,
#    'numActvRevTl': 2,
#    'numBcSats': 0,
#    'numBcTl': 6,
#    'numIlTl': 5,
#    'numOpRevTl': 3,
#    'numRevAccts': 10,
#    'numRevTlBalGt0': 2,
#    'numSats': 7,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 1,
#    'openAcc': 7,
#    'openAcc6m': 0,
#    'openActIl': 3,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 1,
#    'openRv24m': 1,
#    'pctTlNvrDlq': 70,
#    'percentBcGt75': None,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'major_purchase',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:39:42.000-08:00',
#    'revolBal': 3395.0,
#    'revolBalJoint': 38125,
#    'revolUtil': 58.5,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 0,
#    'secAppEarliestCrLine': '1986-04-21T16:00:00.000-08:00',
#    'secAppFicoRangeHigh': 674,
#    'secAppFicoRangeLow': 670,
#    'secAppInqLast6Mths': 1,
#    'secAppMortAcc': 0,
#    'secAppMthsSinceLastMajorDerog': 43,
#    'secAppNumRevAccts': 40,
#    'secAppOpenAcc': 17,
#    'secAppOpenActIl': 0,
#    'secAppRevolUtil': 30.0,
#    'serviceFeeRate': 0.83,
#    'subGrade': 'A2',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 357380,
#    'totHiCredLim': 387615,
#    'totalAcc': 17,
#    'totalBalExMort': 57820,
#    'totalBalIl': 54425.0,
#    'totalBcLimit': 0,
#    'totalCuTl': 2,
#    'totalIlHighCreditLimit': 74515,
#    'totalRevHiLim': 5800},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 7,
#    'acceptD': '2018-02-19T12:06:00.000-08:00',
#    'addrState': 'TN',
#    'addrZip': '374xx',
#    'allUtil': 42.9,
#    'annualInc': 140000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 3432,
#    'bcOpenToBuy': 26093,
#    'bcUtil': 40.6,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-19T12:00:33.000-08:00',
#    'delinq2Yrs': 3,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 12.64,
#    'dtiJoint': None,
#    'earliestCrLine': '1994-08-18T17:00:00.000-07:00',
#    'empLength': 0,
#    'empTitle': 'Director',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 7.0,
#    'ficoRangeHigh': 694,
#    'ficoRangeLow': 690,
#    'fundedAmount': 4200.0,
#    'grade': 'C',
#    'homeOwnership': 'RENT',
#    'housingPayment': 1350.0,
#    'iLUtil': 58.2,
#    'id': 129050031,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 1,
#    'inqLast12m': 4,
#    'inqLast6Mths': 0,
#    'installment': 479.04,
#    'intRate': 14.08,
#    'investorCount': None,
#    'isIncV': 'SOURCE_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 14000.0,
#    'maxBalBc': 6285.0,
#    'memberId': 141963275,
#    'moSinOldIlAcct': 133,
#    'moSinOldRevTlOp': 282,
#    'moSinRcntRevTlOp': 12,
#    'moSinRcntTl': 12,
#    'mortAcc': 10,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': 4,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 42,
#    'mthsSinceRecentBc': 15,
#    'mthsSinceRecentBcDlq': 4,
#    'mthsSinceRecentInq': 0,
#    'mthsSinceRecentRevolDelinq': 4,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 5,
#    'numActvRevTl': 7,
#    'numBcSats': 9,
#    'numBcTl': 13,
#    'numIlTl': 9,
#    'numOpRevTl': 15,
#    'numRevAccts': 32,
#    'numRevTlBalGt0': 7,
#    'numSats': 18,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 1,
#    'openAcc': 18,
#    'openAcc6m': 0,
#    'openActIl': 2,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 1,
#    'openRv24m': 7,
#    'pctTlNvrDlq': 94,
#    'percentBcGt75': 11.1,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:19:06.000-08:00',
#    'revolBal': 25916.0,
#    'revolBalJoint': None,
#    'revolUtil': 38.6,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.07,
#    'subGrade': 'C3',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 65,
#    'totCurBal': 58349,
#    'totHiCredLim': 136109,
#    'totalAcc': 52,
#    'totalBalExMort': 58349,
#    'totalBalIl': 32035.0,
#    'totalBcLimit': 43900,
#    'totalCuTl': 11,
#    'totalIlHighCreditLimit': 55032,
#    'totalRevHiLim': 67200},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 0,
#    'acceptD': '2018-02-21T12:43:15.000-08:00',
#    'addrState': 'GA',
#    'addrZip': '398xx',
#    'allUtil': 86.0,
#    'annualInc': 44000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 1290,
#    'bcOpenToBuy': 210,
#    'bcUtil': 86.0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-21T12:28:49.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 1.77,
#    'dtiJoint': None,
#    'earliestCrLine': '2000-12-20T16:00:00.000-08:00',
#    'empLength': None,
#    'empTitle': None,
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 11.12,
#    'ficoRangeHigh': 704,
#    'ficoRangeLow': 700,
#    'fundedAmount': 10000.0,
#    'grade': 'D',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 686.0,
#    'iLUtil': None,
#    'id': 129130675,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 2,
#    'inqLast6Mths': 0,
#    'installment': 821.98,
#    'intRate': 20.39,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 22000.0,
#    'maxBalBc': 1290.0,
#    'memberId': 142196634,
#    'moSinOldIlAcct': None,
#    'moSinOldRevTlOp': 206,
#    'moSinRcntRevTlOp': 36,
#    'moSinRcntTl': 36,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': None,
#    'mthsSinceRecentBc': 36,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 5,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 1,
#    'numActvRevTl': 1,
#    'numBcSats': 1,
#    'numBcTl': 2,
#    'numIlTl': 0,
#    'numOpRevTl': 1,
#    'numRevAccts': 3,
#    'numRevTlBalGt0': 1,
#    'numSats': 1,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 1,
#    'openAcc6m': 0,
#    'openActIl': 0,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 100.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:44:33.000-08:00',
#    'revolBal': 1290.0,
#    'revolBalJoint': None,
#    'revolUtil': 86.0,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.36,
#    'subGrade': 'D4',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 1290,
#    'totHiCredLim': 1500,
#    'totalAcc': 3,
#    'totalBalExMort': 1290,
#    'totalBalIl': 0.0,
#    'totalBcLimit': 1500,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 0,
#    'totalRevHiLim': 1500},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 9,
#    'acceptD': '2018-02-22T05:55:01.000-08:00',
#    'addrState': 'CA',
#    'addrZip': '902xx',
#    'allUtil': 34.3,
#    'annualInc': 71000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 2585,
#    'bcOpenToBuy': 72026,
#    'bcUtil': 12.2,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-22T05:50:29.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 24.61,
#    'dtiJoint': None,
#    'earliestCrLine': '1998-05-21T17:00:00.000-07:00',
#    'empLength': 120,
#    'empTitle': 'Support coordinator',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 3.8,
#    'ficoRangeHigh': 769,
#    'ficoRangeLow': 765,
#    'fundedAmount': 1525.0,
#    'grade': 'B',
#    'homeOwnership': 'RENT',
#    'housingPayment': 600.0,
#    'iLUtil': 68.2,
#    'id': 129161869,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 1,
#    'inqLast12m': 1,
#    'inqLast6Mths': 1,
#    'installment': 519.37,
#    'intRate': 10.41,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 16000.0,
#    'maxBalBc': 7240.0,
#    'memberId': 142258112,
#    'moSinOldIlAcct': 170,
#    'moSinOldRevTlOp': 237,
#    'moSinRcntRevTlOp': 1,
#    'moSinRcntTl': 1,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': 34,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 7,
#    'mthsSinceRecentBc': 1,
#    'mthsSinceRecentBcDlq': 50,
#    'mthsSinceRecentInq': 4,
#    'mthsSinceRecentRevolDelinq': 34,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 3,
#    'numActvRevTl': 3,
#    'numBcSats': 14,
#    'numBcTl': 22,
#    'numIlTl': 16,
#    'numOpRevTl': 18,
#    'numRevAccts': 33,
#    'numRevTlBalGt0': 3,
#    'numSats': 21,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 5,
#    'openAcc': 21,
#    'openAcc6m': 2,
#    'openActIl': 3,
#    'openIl12m': 1,
#    'openIl24m': 2,
#    'openRv12m': 4,
#    'openRv24m': 7,
#    'pctTlNvrDlq': 95,
#    'percentBcGt75': 0.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T05:56:14.000-08:00',
#    'revolBal': 9974.0,
#    'revolBalJoint': None,
#    'revolUtil': 10.7,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.96,
#    'subGrade': 'B3',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 54288,
#    'totHiCredLim': 158444,
#    'totalAcc': 49,
#    'totalBalExMort': 54288,
#    'totalBalIl': 44314.0,
#    'totalBcLimit': 82000,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 64944,
#    'totalRevHiLim': 93500},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 1,
#    'acceptD': '2018-02-19T20:11:06.000-08:00',
#    'addrState': 'GA',
#    'addrZip': '303xx',
#    'allUtil': 48.8,
#    'annualInc': 160000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 5984,
#    'bcOpenToBuy': 17091,
#    'bcUtil': 42.8,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-11T11:44:21.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 17.17,
#    'dtiJoint': None,
#    'earliestCrLine': '1969-01-10T16:00:00.000-08:00',
#    'empLength': 36,
#    'empTitle': 'Director',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 1.84,
#    'ficoRangeHigh': 804,
#    'ficoRangeLow': 800,
#    'fundedAmount': 5175.0,
#    'grade': 'A',
#    'homeOwnership': 'RENT',
#    'housingPayment': 1800.0,
#    'iLUtil': 45.8,
#    'id': 128534922,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 752.87,
#    'intRate': 5.32,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 25000.0,
#    'maxBalBc': 11332.0,
#    'memberId': 141074977,
#    'moSinOldIlAcct': 177,
#    'moSinOldRevTlOp': 585,
#    'moSinRcntRevTlOp': 56,
#    'moSinRcntTl': 14,
#    'mortAcc': 1,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 14,
#    'mthsSinceRecentBc': 122,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': None,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 2,
#    'numActvRevTl': 3,
#    'numBcSats': 3,
#    'numBcTl': 7,
#    'numIlTl': 4,
#    'numOpRevTl': 8,
#    'numRevAccts': 14,
#    'numRevTlBalGt0': 3,
#    'numSats': 11,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 11,
#    'openAcc6m': 0,
#    'openActIl': 2,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 50.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T09:33:22.000-08:00',
#    'revolBal': 16249.0,
#    'revolBalJoint': None,
#    'revolUtil': 33.1,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.81,
#    'subGrade': 'A1',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 53858,
#    'totHiCredLim': 110381,
#    'totalAcc': 20,
#    'totalBalExMort': 53858,
#    'totalBalIl': 19888.0,
#    'totalBcLimit': 29900,
#    'totalCuTl': 1,
#    'totalIlHighCreditLimit': 43445,
#    'totalRevHiLim': 49100},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'acceptD': '2018-02-22T08:42:21.000-08:00',
#    'addrState': 'NH',
#    'addrZip': '038xx',
#    'allUtil': 25.8,
#    'annualInc': 75000.0,
#    'annualIncJoint': 176000.0,
#    'applicationType': 'JOINT',
#    'avgCurBal': 11984,
#    'bcOpenToBuy': 63943,
#    'bcUtil': 33.4,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-02-11T08:23:18.000-08:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 16.38,
#    'dtiJoint': 19.87,
#    'earliestCrLine': '1994-02-10T16:00:00.000-08:00',
#    'empLength': 120,
#    'empTitle': 'Sole Proprieter',
#    'expD': '2018-03-24T11:00:00.000-07:00',
#    'expDefaultRate': 1.86,
#    'ficoRangeHigh': 804,
#    'ficoRangeLow': 800,
#    'fundedAmount': 2025.0,
#    'grade': 'A',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 3300.0,
#    'iLUtil': 43.0,
#    'id': 128148550,
#    'ilsExpD': '2018-02-22T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 752.76,
#    'intRate': 5.31,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': 'NOT_VERIFIED',
#    'listD': '2018-02-22T10:00:00.000-08:00',
#    'loanAmount': 25000.0,
#    'maxBalBc': 11498.0,
#    'memberId': 141051610,
#    'moSinOldIlAcct': 176,
#    'moSinOldRevTlOp': 288,
#    'moSinRcntRevTlOp': 2,
#    'moSinRcntTl': 2,
#    'mortAcc': 4,
#    'mtgPayment': 3307.33,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 36,
#    'mthsSinceRecentBc': 2,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': None,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 5,
#    'numActvRevTl': 6,
#    'numBcSats': 9,
#    'numBcTl': 10,
#    'numIlTl': 5,
#    'numOpRevTl': 23,
#    'numRevAccts': 30,
#    'numRevTlBalGt0': 6,
#    'numSats': 26,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 1,
#    'openAcc': 26,
#    'openAcc6m': 1,
#    'openActIl': 2,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 1,
#    'openRv24m': 2,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 0.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-02-22T08:49:08.000-08:00',
#    'revolBal': 32076.0,
#    'revolBalJoint': 67788,
#    'revolUtil': 22.2,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 0,
#    'secAppEarliestCrLine': '1994-02-02T16:00:00.000-08:00',
#    'secAppFicoRangeHigh': 779,
#    'secAppFicoRangeLow': 775,
#    'secAppInqLast6Mths': 0,
#    'secAppMortAcc': 4,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': 10,
#    'secAppOpenAcc': 14,
#    'secAppOpenActIl': 3,
#    'secAppRevolUtil': 25.7,
#    'serviceFeeRate': 0.83,
#    'subGrade': 'A1',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 299606,
#    'totHiCredLim': 526261,
#    'totalAcc': 39,
#    'totalBalExMort': 45039,
#    'totalBalIl': 12963.0,
#    'totalBcLimit': 96000,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 30115,
#    'totalRevHiLim': 144600}]}

# %%
data = r.json()
myData = data['loans']

# %% [markdown]
# Save current loan data to ../input/current_loan_list.txt

# %%
with open('../input/current_loan_list.txt', 'w') as outfile:
    json.dump(myData, outfile)

# %%
df_current = pd.read_json('../input/current_loan_list.txt')
df_current.tail()
# Out:
#     accNowDelinq  accOpenPast24Mths                        acceptD addrState  \
# 10             0                  7  2018-02-19T12:06:00.000-08:00        TN
# 11             0                  0  2018-02-21T12:43:15.000-08:00        GA
# 12             0                  9  2018-02-22T05:55:01.000-08:00        CA
# 13             0                  1  2018-02-19T20:11:06.000-08:00        GA
# 14             0                  2  2018-02-22T08:42:21.000-08:00        NH
#
#    addrZip  allUtil  annualInc  annualIncJoint applicationType  avgCurBal  \
# 10   374xx     42.9     140000             NaN      INDIVIDUAL       3432
# 11   398xx     86.0      44000             NaN      INDIVIDUAL       1290
# 12   902xx     34.3      71000             NaN      INDIVIDUAL       2585
# 13   303xx     48.8     160000             NaN      INDIVIDUAL       5984
# 14   038xx     25.8      75000        176000.0           JOINT      11984
#
#         ...        totCollAmt  totCurBal  totHiCredLim  totalAcc  \
# 10      ...                65      58349        136109        52
# 11      ...                 0       1290          1500         3
# 12      ...                 0      54288        158444        49
# 13      ...                 0      53858        110381        20
# 14      ...                 0     299606        526261        39
#
#    totalBalExMort  totalBalIl  totalBcLimit  totalCuTl totalIlHighCreditLimit  \
# 10          58349       32035         43900         11                  55032
# 11           1290           0          1500          0                      0
# 12          54288       44314         82000          0                  64944
# 13          53858       19888         29900          1                  43445
# 14          45039       12963         96000          0                  30115
#
#     totalRevHiLim
# 10          67200
# 11           1500
# 12          93500
# 13          49100
# 14         144600
#
# [5 rows x 119 columns]

# %% [markdown]
# ## 2. Get Historical Data

# %% [markdown]
# Historical data of 2014 were downloaded in https://www.lendingclub.com/info/download-data.action and saved in ../input/2014LoanStats3c.csv

# %%
df_2014 = pd.read_csv('../input/2014LoanStats3c.csv', skiprows=1, low_memory=False)

# %%
df_2014.shape
# Out:
# (235631, 145)

# %%
print(df_2014.head())
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    15000.0      15000.0          15000.0   60 months
# 1  NaN        NaN    10400.0      10400.0          10400.0   36 months
# 2  NaN        NaN    21425.0      21425.0          21425.0   60 months
# 3  NaN        NaN    12800.0      12800.0          12800.0   60 months
# 4  NaN        NaN     7650.0       7650.0           7650.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   12.39%       336.64     C        C1       ...
# 1    6.99%       321.08     A        A3       ...
# 2   15.59%       516.36     D        D1       ...
# 3   17.14%       319.08     D        D4       ...
# 4   13.66%       260.20     C        C3       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]

# %%
list(df_current)
# Out:
# ['accNowDelinq',
#  'accOpenPast24Mths',
#  'acceptD',
#  'addrState',
#  'addrZip',
#  'allUtil',
#  'annualInc',
#  'annualIncJoint',
#  'applicationType',
#  'avgCurBal',
#  'bcOpenToBuy',
#  'bcUtil',
#  'chargeoffWithin12Mths',
#  'collections12MthsExMed',
#  'creditPullD',
#  'delinq2Yrs',
#  'delinqAmnt',
#  'desc',
#  'disbursementMethod',
#  'dti',
#  'dtiJoint',
#  'earliestCrLine',
#  'empLength',
#  'empTitle',
#  'expD',
#  'expDefaultRate',
#  'ficoRangeHigh',
#  'ficoRangeLow',
#  'fundedAmount',
#  'grade',
#  'homeOwnership',
#  'housingPayment',
#  'iLUtil',
#  'id',
#  'ilsExpD',
#  'initialListStatus',
#  'inqFi',
#  'inqLast12m',
#  'inqLast6Mths',
#  'installment',
#  'intRate',
#  'investorCount',
#  'isIncV',
#  'isIncVJoint',
#  'listD',
#  'loanAmount',
#  'maxBalBc',
#  'memberId',
#  'moSinOldIlAcct',
#  'moSinOldRevTlOp',
#  'moSinRcntRevTlOp',
#  'moSinRcntTl',
#  'mortAcc',
#  'mtgPayment',
#  'mthsSinceLastDelinq',
#  'mthsSinceLastMajorDerog',
#  'mthsSinceLastRecord',
#  'mthsSinceRcntIl',
#  'mthsSinceRecentBc',
#  'mthsSinceRecentBcDlq',
#  'mthsSinceRecentInq',
#  'mthsSinceRecentRevolDelinq',
#  'numAcctsEver120Ppd',
#  'numActvBcTl',
#  'numActvRevTl',
#  'numBcSats',
#  'numBcTl',
#  'numIlTl',
#  'numOpRevTl',
#  'numRevAccts',
#  'numRevTlBalGt0',
#  'numSats',
#  'numTl120dpd2m',
#  'numTl30dpd',
#  'numTl90gDpd24m',
#  'numTlOpPast12m',
#  'openAcc',
#  'openAcc6m',
#  'openActIl',
#  'openIl12m',
#  'openIl24m',
#  'openRv12m',
#  'openRv24m',
#  'pctTlNvrDlq',
#  'percentBcGt75',
#  'pubRec',
#  'pubRecBankruptcies',
#  'purpose',
#  'reviewStatus',
#  'reviewStatusD',
#  'revolBal',
#  'revolBalJoint',
#  'revolUtil',
#  'secAppChargeoffWithin12Mths',
#  'secAppCollections12MthsExMed',
#  'secAppEarliestCrLine',
#  'secAppFicoRangeHigh',
#  'secAppFicoRangeLow',
#  'secAppInqLast6Mths',
#  'secAppMortAcc',
#  'secAppMthsSinceLastMajorDerog',
#  'secAppNumRevAccts',
#  'secAppOpenAcc',
#  'secAppOpenActIl',
#  'secAppRevolUtil',
#  'serviceFeeRate',
#  'subGrade',
#  'taxLiens',
#  'term',
#  'totCollAmt',
#  'totCurBal',
#  'totHiCredLim',
#  'totalAcc',
#  'totalBalExMort',
#  'totalBalIl',
#  'totalBcLimit',
#  'totalCuTl',
#  'totalIlHighCreditLimit',
#  'totalRevHiLim']

# %%
list(df_2014)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'revol_bal_joint',
#  'sec_app_earliest_cr_line',
#  'sec_app_inq_last_6mths',
#  'sec_app_mort_acc',
#  'sec_app_open_acc',
#  'sec_app_revol_util',
#  'sec_app_open_act_il',
#  'sec_app_num_rev_accts',
#  'sec_app_chargeoff_within_12_mths',
#  'sec_app_collections_12_mths_ex_med',
#  'sec_app_mths_since_last_major_derog',
#  'hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'deferral_term',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'payment_plan_start_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'orig_projected_additional_accrued_interest',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount',
#  'disbursement_method',
#  'debt_settlement_flag',
#  'debt_settlement_flag_date',
#  'settlement_status',
#  'settlement_date',
#  'settlement_amount',
#  'settlement_percentage',
#  'settlement_term']

# %% [markdown]
# ## 3. Format Conversion of Feature Names

# %% [markdown]
# Feature names and the number of features are different for current loan and 2014 historical data. It is nessary to unifiy the feature names and keep only the common features for analysis.

# %%
current_feature = list(df_current.columns.values)

for i in range(len(current_feature)):
    current_feature[i] = str.lower(str(current_feature[i]))

current_feature[:5]
# Out:
# ['accnowdelinq', 'accopenpast24mths', 'acceptd', 'addrstate', 'addrzip']

# %%
his_feature = list(df_2014.columns.values)

for i in range(len(his_feature)):
    his_feature[i] = str(his_feature[i].replace('_',''))

his_feature[:5]
# Out:
# ['id', 'memberid', 'loanamnt', 'fundedamnt', 'fundedamntinv']

# %%
common_feature = set(his_feature)&(set(current_feature))
print(len(common_feature))
print(common_feature)
# Out:
# 97
# {'disbursementmethod', 'secappopenactil', 'numactvrevtl', 'emplength', 'totalrevhilim', 'mosinoldrevtlop', 'pcttlnvrdlq', 'numbctl', 'openil24m', 'installment', 'collections12mthsexmed', 'mosinoldilacct', 'mosinrcntrevtlop', 'chargeoffwithin12mths', 'totalbalexmort', 'taxliens', 'numtloppast12m', 'secappearliestcrline', 'earliestcrline', 'bcopentobuy', 'totalilhighcreditlimit', 'numsats', 'numtl120dpd2m', 'subgrade', 'mthssincerecentbcdlq', 'totcurbal', 'openrv12m', 'mthssincelastdelinq', 'numactvbctl', 'applicationtype', 'secappmortacc', 'numoprevtl', 'mthssincerecentrevoldelinq', 'openacc6m', 'secappopenacc', 'totalbclimit', 'tothicredlim', 'totalcutl', 'pubrecbankruptcies', 'secapprevolutil', 'inqfi', 'initialliststatus', 'secappnumrevaccts', 'accnowdelinq', 'term', 'delinq2yrs', 'intrate', 'annualinc', 'inqlast12m', 'dti', 'grade', 'avgcurbal', 'allutil', 'homeownership', 'addrstate', 'secappchargeoffwithin12mths', 'mthssincelastrecord', 'inqlast6mths', 'delinqamnt', 'pubrec', 'numrevaccts', 'revolutil', 'maxbalbc', 'secappinqlast6mths', 'accopenpast24mths', 'mosinrcnttl', 'mthssincerecentinq', 'numbcsats', 'mthssincerecentbc', 'numtl90gdpd24m', 'emptitle', 'annualincjoint', 'secappmthssincelastmajorderog', 'id', 'dtijoint', 'mthssincelastmajorderog', 'openrv24m', 'percentbcgt75', 'memberid', 'ilutil', 'numrevtlbalgt0', 'bcutil', 'mthssincercntil', 'totalbalil', 'purpose', 'openacc', 'revolbal', 'secappcollections12mthsexmed', 'desc', 'numtl30dpd', 'totalacc', 'mortacc', 'openactil', 'totcollamt', 'revolbaljoint', 'numiltl', 'openil12m'}

# %%
his_unique = set(his_feature)-set(current_feature)
print(len(his_unique))
print(his_unique)
# Out:
# 48
# {'debtsettlementflag', 'totalrecprncp', 'hardshipenddate', 'loanstatus', 'verificationstatusjoint', 'settlementterm', 'totalpymntinv', 'issued', 'nextpymntd', 'totalpymnt', 'hardshiptype', 'settlementdate', 'outprncp', 'hardshipdpd', 'collectionrecoveryfee', 'hardshipreason', 'fundedamntinv', 'numacctsever120pd', 'zipcode', 'hardshipstartdate', 'settlementpercentage', 'pymntplan', 'verificationstatus', 'outprncpinv', 'hardshippayoffbalanceamount', 'lastpymntd', 'hardshiplength', 'origprojectedadditionalaccruedinterest', 'fundedamnt', 'lastpymntamnt', 'deferralterm', 'settlementamount', 'recoveries', 'url', 'loanamnt', 'title', 'totalreclatefee', 'lastcreditpulld', 'paymentplanstartdate', 'hardshipamount', 'hardshiplastpaymentamount', 'hardshipstatus', 'debtsettlementflagdate', 'policycode', 'settlementstatus', 'hardshiploanstatus', 'totalrecint', 'hardshipflag'}

# %%
current_unique = set(current_feature)-set(his_feature)
print(len(current_unique))
print(current_unique)
# Out:
# 22
# {'mtgpayment', 'acceptd', 'ficorangehigh', 'fundedamount', 'addrzip', 'expd', 'secappficorangehigh', 'reviewstatusd', 'secappficorangelow', 'ficorangelow', 'isincvjoint', 'listd', 'ilsexpd', 'investorcount', 'isincv', 'housingpayment', 'expdefaultrate', 'reviewstatus', 'loanamount', 'creditpulld', 'servicefeerate', 'numacctsever120ppd'}

# %%
feature_dic = {}
feature_dic['common_feature'] = common_feature
feature_dic['his_unique'] = his_unique
feature_dic['current_unique'] = current_unique

# %% [markdown]
# There are common features that have different name in current loan data and historical loan data. Unify this case to be historical data feature names.

# %%
common_feature = common_feature.union({'zipcode',
                                       'fundedamnt',
                                       'verificationstatus',
                                       'verificationstatusjoint',
                                       'loanamnt',
                                       'numacctsever120pd'})
len(common_feature)
# Out:
# 103

# %% [markdown]
# ## 4. Generate Training and Testing Datasets

# %% [markdown]
# Convert Column Names in Dataframe and Save Dataframe with common features and issued, loanstatus.

# %%
for col in df_2014.columns.values:
    df_2014.rename(columns={str(col): str(col).replace('_','')}, inplace=True)

# %%
df_2014 = df_2014[list(common_feature)+['issued','loanstatus']]

# %%
df_2014.shape
# Out:
# (235631, 105)

# %%
df_2014.to_csv('../input/loan_2014_prp.csv', index=False)
